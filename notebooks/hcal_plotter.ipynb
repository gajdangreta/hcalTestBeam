# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#305,307,300
E_in=[300,300,4000]
E_out=[36.54,36.55,352.66]
E_dev=[18.27,18.4,37.55]

# %%
plt.errorbar(E_in, E_out, E_dev, linestyle='--', marker='o')
# Out:
# <ErrorbarContainer object of 3 artists>
